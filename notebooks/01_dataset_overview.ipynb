# %%
import os
import warnings
import librosa
import librosa.display
import matplotlib.pyplot as plt

# ---- Silence unnecessary warnings ----
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

# ---- Automatically set working directory (optional) ----
# Replace this with your actual project folder if needed
os.chdir(r"C:\Users\aadit\Documents\Codes\Music Genre identification")

# ---- Define full absolute path to your audio file ----
audio_path = r"Data\genres_original\blues\blues.00000.wav"

# ---- Verify file exists ----
if not os.path.exists(audio_path):
    raise FileNotFoundError(f"File not found at {audio_path}")

# ---- Load the audio ----
y, sr = librosa.load(audio_path, sr=22050)
print(f"✅ Audio loaded successfully!")
print(f"Sample rate: {sr}")
print(f"Duration: {len(y)/sr:.2f} seconds")

# ---- Plot waveform ----
plt.figure(figsize=(12, 3))
librosa.display.waveshow(y, sr=sr)
plt.title("Waveform of the Example Track")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.show()

# ---- Compute and plot MFCCs ----
mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)
plt.figure(figsize=(10, 4))
librosa.display.specshow(mfccs, x_axis='time', sr=sr)
plt.colorbar(label='MFCC Coefficients')
plt.title("MFCCs (13 Coefficients)")
plt.tight_layout()
plt.show()
# Out:
# ✅ Audio loaded successfully!
# Sample rate: 22050
# Duration: 30.01 seconds
